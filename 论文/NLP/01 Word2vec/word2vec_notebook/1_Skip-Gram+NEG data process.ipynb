# %% [markdown]
# # Skip-Gram+NGE数据处理模块

# %% [markdown]
# **目录：**
# 1. 词表构建
#
# 2. 正样本生成
#
# 3. 负样本采样
#
# 4. 负样本生成
#
# ---

# %%
import numpy as np
from collections import deque

# %%
input_file = open("./data/text8.txt","r",encoding="utf-8")

# %%
def _init_dict(min_count):
    word_count_sum = 0
    sentence_count = 0
    word2id_dict = dict()
    id2word_dict = dict()
    wordid_frequency_dict = dict()
    word_freq = dict()
    for line in input_file:
        line = line.strip().split()
        word_count_sum +=len(line)
        sentence_count +=1
        for i,word in enumerate(line):
            if i%1000000==0:
                print (i,len(line))
            if word_freq.get(word)==None:
                word_freq[word] = 1
            else:
                word_freq[word] += 1
    for i,word in enumerate(word_freq):
        if i % 100000 == 0:
            print(i, len(word_freq))
            # 如果小于min_count就将他视为比较稀有的词，忽略
        if word_freq[word]<min_count:
            # 总的词频减去这个词的词频
            word_count_sum -= word_freq[word]
            continue
        word2id_dict[word] = len(word2id_dict) # 按照顺序下去，第几个进入的词分配第几
        id2word_dict[len(id2word_dict)] = word # 同样是按照顺序排下去
        wordid_frequency_dict[len(word2id_dict)-1] = word_freq[word]
    word_count =len(word2id_dict) # 去重之后词数量
    return word2id_dict,id2word_dict,wordid_frequency_dict

# %%
word2id_dict,id2word_dict,wordid_frequency_dict = _init_dict(3)
# Out:
# 0 17005207
# 1000000 17005207
# 2000000 17005207
# 3000000 17005207
# 4000000 17005207
# 5000000 17005207
# 6000000 17005207
# 7000000 17005207
# 8000000 17005207
# 9000000 17005207
# 10000000 17005207
# 11000000 17005207
# 12000000 17005207
# 13000000 17005207
# 14000000 17005207
# 15000000 17005207
# 16000000 17005207
# 17000000 17005207
# 0 253854
# 100000 253854
# 200000 253854

# %%
word2id_dict
# Out:
# {'certifying': 0,
#  'evaders': 1,
#  'bilabial': 2,
#  'fealty': 3,
#  'joeseph': 4,
#  'yozei': 56307,
#  'obliterating': 5,
#  'vyacheslav': 49833,
#  'hangout': 6,
#  'customizable': 49834,
#  'uruguayan': 7,
#  'cltl': 8,
#  'die': 9,
#  'tabasco': 10,
#  'mayflower': 11,
#  'rooted': 12,
#  'bloomers': 49835,
#  'bonnett': 13,
#  'supercalifragilisticexpialidocious': 14,
#  'lattuada': 49836,
#  'unpretentious': 15,
#  'euglenids': 49837,
#  'magnolias': 83414,
#  'aldohexose': 49839,
#  'chandarli': 16,
#  'confederaci': 49841,
#  'fatalistic': 49842,
#  'tongues': 17,
#  'anwar': 91628,
#  'independencia': 77,
#  'progressives': 49844,
#  'envied': 49845,
#  'gao': 18,
#  'gyro': 19,
#  'immersions': 55197,
#  'wrongdoings': 107,
#  'propitious': 49847,
#  'sanding': 16859,
#  'prospered': 20,
#  'goddamn': 49848,
#  'pueblos': 49849,
#  'enciclopedia': 21,
#  'gelobet': 22,
#  'lutterworth': 23,
#  'carthusians': 89219,
#  'doubs': 24,
#  'editio': 49852,
#  'iahp': 49853,
#  'assurbanipal': 26,
#  'tora': 27,
#  'liberale': 28,
#  'stevie': 29,
#  'madhyamika': 148,
#  'adiation': 41236,
#  'patient': 30,
#  'stroud': 49857,
#  'latifah': 31,
#  'affan': 16861,
#  'autonomist': 49858,
#  'gallows': 49859,
#  'figuration': 32,
#  'bucking': 33,
#  'matographe': 34,
#  'spurred': 49860,
#  'blunden': 49861,
#  'lina': 35,
#  'crv': 36,
#  'entangling': 189,
#  'realign': 49864,
#  'hollies': 49865,
#  'cadastral': 49866,
#  'tony': 49867,
#  'contended': 37,
#  'chastain': 38,
#  'politcal': 215,
#  'philby': 15311,
#  'cabos': 4556,
#  'shahada': 40,
#  'othman': 41,
#  'cullinan': 42,
#  'novodevichy': 43,
#  'gigo': 44,
#  'communicable': 45,
#  'wolverines': 46,
#  'soars': 49873,
#  'mortgage': 98410,
#  'distinctively': 47,
#  'provable': 48,
#  'mobilise': 49,
#  'utena': 49875,
#  'jamais': 50,
#  'secedes': 95110,
#  'ur': 51,
#  'rightists': 49876,
#  'gradient': 49877,
#  'aleksei': 49878,
#  'hamiltonian': 52,
#  'goosetave': 318,
#  'zygote': 53,
#  'bainbridge': 54,
#  'marshalsea': 84074,
#  'aasen': 55,
#  'sundial': 56,
#  'ultrasound': 49880,
#  'nourished': 49881,
#  'marten': 16863,
#  'parser': 57,
#  'gymnosperm': 49882,
#  'obsoletes': 49883,
#  'sane': 58,
#  'habere': 49884,
#  'noun': 60,
#  'mitcham': 49840,
#  'hurting': 49886,
#  'frelimo': 49887,
#  'afdb': 61,
#  'henriette': 49888,
#  'variance': 381,
#  'naivety': 47052,
#  'gyoku': 49889,
#  'dilutes': 49890,
#  'intertextual': 63,
#  'transport': 64,
#  'bryozoans': 49891,
#  'stasi': 65,
#  'hydrohalic': 17448,
#  'corrupted': 49892,
#  'jog': 66,
#  'creditor': 67,
#  'np': 69,
#  'battlemech': 70,
#  'administrations': 71,
#  'cry': 49895,
#  'caton': 72,
#  'blurb': 49896,
#  'lvarez': 49897,
#  'defected': 49898,
#  'satirist': 5411,
#  'jutsu': 74,
#  'remote': 75,
#  'mentioned': 8565,
#  'srgb': 76,
#  'sidenote': 49843,
#  'cytosine': 78,
#  'rcfile': 83425,
#  'observing': 79,
#  'guanaco': 49902,
#  'hosea': 80,
#  'heath': 81,
#  'flushing': 49905,
#  'irishmen': 82,
#  'politicized': 83,
#  'loom': 84,
#  'cutback': 85,
#  'pseudonym': 49907,
#  'virtue': 49908,
#  'richest': 49909,
#  'proximity': 86,
#  'breen': 87,
#  'linx': 49910,
#  'nose': 28870,
#  'begets': 49911,
#  'sina': 88,
#  'butlerian': 49912,
#  'graeco': 49913,
#  'emphasises': 99542,
#  'bremerton': 90,
#  'corkscrew': 91,
#  'geniality': 92,
#  'quills': 563,
#  'sikander': 49915,
#  'rathaus': 97742,
#  'boudoir': 93,
#  'batgirl': 89648,
#  'solidification': 94,
#  'founding': 49917,
#  'daugava': 96,
#  'teleportation': 91638,
#  'soteira': 98,
#  'regnal': 99,
#  'coello': 100,
#  'lasso': 607,
#  'linea': 49919,
#  'freie': 102,
#  'slagelse': 16870,
#  'estrogen': 621,
#  'ripon': 103,
#  'newsstand': 49921,
#  'tanners': 49922,
#  'seeming': 49923,
#  'biruni': 49924,
#  'militari': 104,
#  'bng': 105,
#  'eri': 642,
#  'artworks': 106,
#  'neurone': 651,
#  'anahata': 49929,
#  'delicacies': 658,
#  'gathers': 75236,
#  'pryce': 49930,
#  'author': 49931,
#  'wrestlers': 49932,
#  'winery': 108,
#  'mondegreens': 49933,
#  'capoeira': 49934,
#  'am': 94256,
#  'ancaster': 49935,
#  'nner': 109,
#  'thurs': 110,
#  'hotelier': 49936,
#  'kuhr': 111,
#  'maidservants': 41565,
#  'lxvi': 113,
#  'landet': 698,
#  'yuuji': 49938,
#  'blo': 41566,
#  'senor': 115,
#  'grunewald': 116,
#  'kalapa': 36209,
#  'mda': 49941,
#  'frend': 75239,
#  'riband': 99096,
#  'anglo': 49943,
#  'musicologists': 117,
#  'trofim': 49944,
#  'lmi': 119,
#  'fang': 8574,
#  'raving': 120,
#  'auzout': 757,
#  'khafre': 49945,
#  'zipwith': 121,
#  'wart': 49946,
#  'menachem': 49947,
#  'argos': 122,
#  'expertise': 49948,
#  'swoop': 123,
#  'hernando': 49949,
#  'grimsel': 124,
#  'marpat': 783,
#  'diverse': 49950,
#  'aeron': 125,
#  'dragon': 49952,
#  'nabataean': 49953,
#  'entente': 126,
#  'grog': 49850,
#  'aphrodisiac': 49956,
#  'plame': 802,
#  'vladislav': 127,
#  'yaqub': 128,
#  'bitstream': 129,
#  'cmas': 91652,
#  'drifted': 49958,
#  'kambojas': 49959,
#  'supremo': 95965,
#  'waerden': 75241,
#  'turenne': 130,
#  'cosine': 131,
#  'biosecurity': 132,
#  'brancusi': 49962,
#  'zirconium': 133,
#  'skeleton': 134,
#  'rockets': 135,
#  'volte': 49963,
#  'mobilizes': 49964,
#  'attraction': 136,
#  'sdr': 137,
#  'coreper': 94027,
#  'tonally': 138,
#  'blackrock': 139,
#  'donaggio': 49965,
#  'republika': 140,
#  'rested': 141,
#  'niflheim': 49967,
#  'dumplings': 49968,
#  'roofless': 142,
#  'revolutionist': 143,
#  'poppaea': 8580,
#  'kerner': 49970,
#  'ossetian': 79260,
#  'favorites': 144,
#  'krimson': 907,
#  'inuyasha': 145,
#  'injection': 49972,
#  'siglo': 49855,
#  'recht': 49974,
#  'arexx': 920,
#  'gwadar': 7507,
#  'electorate': 49977,
#  'biblioth': 49978,
#  'blockades': 146,
#  'mendelism': 147,
#  'loran': 49979,
#  'fenders': 149,
#  'often': 150,
#  'zawahiri': 151,
#  'chebar': 152,
#  'velupillai': 153,
#  'monterrey': 49982,
#  'inappropriately': 154,
#  'jang': 967,
#  'pent': 41574,
#  'ere': 156,
#  'bivalent': 49983,
#  'fiske': 49984,
#  'partaking': 157,
#  'fractional': 988,
#  'empted': 49985,
#  'behistun': 49986,
#  'tripucka': 49987,
#  'manservant': 49988,
#  'sinaltrainal': 49989,
#  'friars': 160,
#  'skin': 161,
#  'hurley': 49992,
#  'maupassant': 49993,
#  'toggle': 163,
#  'wonderswan': 49994,
#  'widdecombe': 165,
#  'pack': 166,
#  'affirmative': 167,
#  'metropolitana': 168,
#  'polynesian': 49996,
#  'prioritise': 8386,
#  'earthshine': 169,
#  'revolves': 33341,
#  'togethers': 171,
#  'pepsico': 49998,
#  'alejandro': 172,
#  'kamov': 1051,
#  'shramek': 49999,
#  'crewmember': 50000,
#  'numbat': 174,
#  'iguanodon': 83442,
#  'weser': 50001,
#  'bioy': 50002,
#  'guinness': 175,
#  'isserles': 66958,
#  'kumar': 64483,
#  'subscribers': 178,
#  'bourguignon': 10339,
#  'newark': 179,
#  'potentially': 180,
#  'bernanke': 182,
#  'suspends': 50004,
#  'fractionating': 50005,
#  'steamboats': 49862,
#  'res': 32951,
#  'rok': 24276,
#  'dozenal': 50006,
#  'qualifies': 50008,
#  'azali': 1126,
#  'sweeney': 183,
#  'stunningly': 184,
#  'tantra': 185,
#  'bradman': 50010,
#  'mustaqbal': 1135,
#  'miyazawa': 50011,
#  'multiphase': 50012,
#  'magneto': 188,
#  'menahem': 49863,
#  'nobility': 1147,
#  'jeep': 50013,
#  'chances': 41579,
#  'liliales': 50016,
#  'atchison': 89741,
#  'houck': 191,
#  'squeak': 50017,
#  'utensils': 1162,
#  'schwarzenegger': 48153,
#  'weisbord': 192,
#  'heshvan': 193,
#  'bcg': 50019,
#  'ribbons': 50020,
#  'appeal': 194,
#  'spirituali': 8591,
#  'ritt': 195,
#  'cerberus': 50022,
#  'enchiladas': 50023,
#  'replenish': 197,
#  'jamnia': 198,
#  'dupe': 96284,
#  'mistakenly': 1202,
#  'arrests': 199,
#  'scissors': 50028,
#  'numberless': 75251,
#  'capsid': 201,
#  'dahlhaus': 202,
#  'agitators': 21164,
#  'couto': 203,
#  'overhears': 204,
#  'looptail': 50031,
#  'nemo': 75253,
#  'haight': 8592,
#  'mirrors': 50033,
#  'fmv': 50034,
#  'discards': 205,
#  'shabd': 50035,
#  'sasson': 50036,
#  'neelam': 91660,
#  'cushion': 206,
#  'counteract': 50038,
#  'resumes': 1257,
#  'morley': 207,
#  'boninsegna': 208,
#  'stipulate': 209,
#  'rake': 50039,
#  'pts': 33350,
#  'olave': 210,
#  'entrees': 211,
#  'cosmopolitanism': 50040,
#  'pessimistic': 50041,
#  'disparaging': 212,
#  'svga': 213,
#  'bomarc': 50042,
#  'interlingua': 214,
#  'siting': 49869,
#  'rto': 1277,
#  'truths': 216,
#  'gjallarhorn': 50044,
#  'globally': 1282,
#  'winterbottom': 50045,
#  'doolish': 50046,
#  'bellevue': 50047,
#  'shellfish': 217,
#  'nestorius': 92821,
#  'cllr': 218,
#  'supercup': 94937,
#  'jaeger': 50049,
#  'spm': 91662,
#  'loeb': 219,
#  'chapultepec': 220,
#  'dsd': 50050,
#  'anchors': 221,
#  'bgn': 222,
#  'retardant': 223,
#  'poz': 224,
#  'pdfs': 50053,
#  'wracked': 225,
#  'kathleen': 50054,
#  'chromophore': 50055,
#  'traviata': 50056,
#  'lehmer': 226,
#  'takamine': 50057,
#  'transcriptase': 227,
#  'slaved': 228,
#  'derrek': 230,
#  'sirmium': 50059,
#  'pennsylvania': 50060,
#  'paleontology': 50061,
#  'ronnie': 50062,
#  'diamonds': 50063,
#  'airman': 232,
#  'grahame': 50064,
#  'macmahon': 233,
#  'complaint': 234,
#  'alvis': 235,
#  'aiki': 236,
#  'dactylic': 43766,
#  'cafta': 1434,
#  'documenting': 50068,
#  'aphrodite': 237,
#  'slav': 50069,
#  'illuminated': 50070,
#  'readings': 238,
#  'scorekeeping': 239,
#  'buke': 50072,
#  'paktia': 50073,
#  'mio': 75258,
#  'pursues': 50075,
#  'pather': 240,
#  'aptly': 8601,
#  'saturation': 50076,
#  'attracts': 49870,
#  'ornithologische': 91668,
#  'rohr': 242,
#  'kaufmann': 1482,
#  'reginae': 83457,
#  'pleonasm': 91669,
#  'ffff': 33360,
#  'yog': 244,
#  'bombardments': 50081,
#  'goldhagen': 50082,
#  'extractive': 50083,
#  'desai': 1507,
#  'gilgal': 58840,
#  'thud': 247,
#  'felling': 22854,
#  'cups': 248,
#  'logudorese': 249,
#  'pendergast': 250,
#  'koans': 251,
#  'byu': 1530,
#  'par': 50087,
#  'fivondronampokontany': 253,
#  'vulva': 67099,
#  'travelled': 254,
#  'kee': 91673,
#  'disallowing': 256,
#  'scars': 257,
#  'endearing': 258,
#  'desulfurization': 259,
#  'raiders': 260,
#  'honoured': 261,
#  'resigns': 262,
#  'talent': 263,
#  'unfermented': 264,
#  'ourselves': 265,
#  'yeoman': 83460,
#  'shun': 50094,
#  'spiralled': 266,
#  'duvall': 267,
#  'antiquarian': 268,
#  'stew': 50095,
#  'violist': 50096,
#  'bewegung': 269,
#  'callahan': 270,
#  'kafiristan': 271,
#  'sanctum': 50098,
#  'compi': 50099,
#  'dzogchen': 53137,
#  'ignacio': 50101,
#  'mothballed': 273,
#  'raiola': 274,
#  'welding': 275,
#  'adverb': 276,
#  'roslin': 277,
#  'consequentialism': 278,
#  'hazing': 1617,
#  'potting': 279,
#  'peristyle': 280,
#  'crowd': 1627,
#  'xv': 281,
#  'woodbridge': 282,
#  'prosecuted': 50104,
#  'wegbaja': 50105,
#  'willpower': 283,
#  'portsea': 284,
#  'weird': 285,
#  'tricyclic': 50106,
#  'kirkland': 286,
#  'kindled': 287,
#  'myoclonic': 288,
#  'stewie': 50108,
#  'flown': 50109,
#  'supersymmetry': 289,
#  'fomorians': 50110,
#  'mayans': 50111,
#  'jedec': 290,
#  'jouvenel': 50112,
#  'alumnus': 50113,
#  'dundalk': 29940,
#  'bitchx': 1695,
#  'observe': 291,
#  'civilizing': 292,
#  'dowels': 50115,
#  'haas': 293,
#  'contrasting': 294,
#  'mymicronesia': 33367,
#  'longchamp': 1712,
#  'lieutenants': 295,
#  'confound': 50117,
#  'farthest': 8605,
#  'tuff': 296,
#  'baserunner': 50120,
#  'deregulating': 90232,
#  'deeply': 297,
#  'heilbroner': 82253,
#  'nadph': 298,
#  'potsdam': 299,
#  'hardpoints': 1737,
#  'pendleton': 300,
#  'hyperlinked': 301,
#  'considering': 303,
#  'jonben': 50123,
#  'beleriand': 304,
#  'backhand': 54991,
#  'hanna': 16898,
#  'boarding': 50124,
#  'hsin': 50125,
#  'faure': 305,
#  'aarseth': 50126,
#  'milanesas': 50127,
#  'unbreakable': 306,
#  'lec': 307,
#  'tigin': 1787,
#  'constantinus': 308,
#  'medallist': 50129,
#  'tolman': 50130,
#  'cans': 50131,
#  'escola': 92083,
#  'scout': 50132,
#  'bonding': 309,
#  'jesse': 310,
#  'prelates': 311,
#  'warehouse': 312,
#  'mackinaw': 313,
#  'driftwood': 50134,
#  'matrimonio': 50135,
#  'couvet': 50136,
#  'lowercamelcase': 91642,
#  'salon': 314,
#  'mcnichol': 50137,
#  'littrow': 315,
#  'gaber': 50138,
#  'ascetics': 50139,
#  'biyat': 1856,
#  'largemouth': 316,
#  'brigades': 317,
#  'theresa': 50140,
#  'alistair': 50142,
#  'butterflies': 50144,
#  'marathons': 49879,
#  'ohrid': 50145,
#  'betterment': 319,
#  'flat': 320,
#  'awt': 321,
#  'mandating': 66971,
#  'bombardment': 322,
#  'flees': 50148,
#  'isolating': 1904,
#  'boot': 50150,
#  'grunts': 323,
#  'jacqueline': 324,
#  'magnesians': 1916,
#  'flatland': 50151,
#  'videogames': 327,
#  'morison': 1926,
#  'idr': 328,
#  'concisely': 329,
#  'insularum': 50154,
#  'ducatus': 50155,
#  'curry': 50156,
#  'clapping': 16902,
#  'physical': 330,
#  'ardalan': 331,
#  'decorating': 332,
#  'whirlwind': 63839,
#  'hermit': 50158,
#  'recirculation': 333,
#  'nonfiction': 334,
#  'artemis': 8614,
#  'ramprasad': 1974,
#  'sejm': 335,
#  'swagger': 1894,
#  'windsurfing': 336,
#  'intramuscularly': 337,
#  'ctr': 338,
#  'solidbody': 50165,
#  'nuer': 339,
#  'partite': 36259,
#  'taps': 50167,
#  'untruthful': 45525,
#  'assizes': 50169,
#  'cac': 2007,
#  'leq': 340,
#  'rotunda': 341,
#  'passion': 50172,
#  'palutena': 96443,
#  'amv': 342,
#  'whereby': 343,
#  'pantheon': 33375,
#  'toaster': 344,
#  'woods': 50174,
#  'vivisection': 50175,
#  'spelea': 75276,
#  'matriarch': 50176,
#  'drinks': 50177,
#  'post': 345,
#  'doce': 87911,
#  'institutions': 346,
#  'vremya': 50178,
#  'eaten': 50179,
#  'cloyne': 91685,
#  'collusive': 347,
#  'boye': 18042,
#  'inmarsat': 17136,
#  'imperceptible': 91686,
#  'iori': 50180,
#  'phosphorylated': 50181,
#  'xy': 348,
#  'brca': 50182,
#  'abhorrence': 50183,
#  'verdict': 18995,
#  'motagua': 5243,
#  'randolph': 50185,
#  'troezen': 350,
#  'catherine': 50186,
#  'groucho': 50187,
#  'perpendicularly': 351,
#  'jean': 352,
#  'burckhardt': 2113,
#  'engelhard': 50188,
#  'quinidine': 50190,
#  'skimmers': 50191,
#  'grenzen': 63861,
#  'dff': 50192,
#  'vci': 355,
#  'belafonte': 50193,
#  'dusts': 2139,
#  'peeters': 357,
#  'besiegers': 50194,
#  'schemata': 50195,
#  'birt': 358,
#  'uks': 359,
#  'ethanol': 360,
#  'pulps': 361,
#  'warlordism': 50196,
#  'yury': 50197,
#  'silhouette': 75283,
#  'mattie': 50199,
#  'explanations': 70867,
#  'impresses': 362,
#  'debunks': 363,
#  'furcal': 49885,
#  'warnings': 364,
#  'isa': 50200,
#  'entrained': 365,
#  'mcbee': 366,
#  'blaurock': 50204,
#  'contractile': 50205,
#  'saavedra': 50206,
#  'ula': 24325,
#  'succour': 50208,
#  'bhai': 50209,
#  'earthbound': 367,
#  'vernacular': 368,
#  'goldstone': 50211,
#  'invents': 50212,
#  'mismatch': 369,
#  'synch': 370,
#  'freudianism': 371,
#  'gadamer': 50214,
#  'essay': 372,
#  'demarcating': 50215,
#  'researching': 50216,
#  'plies': 373,
#  'annette': 50217,
#  'betters': 50218,
#  'hamath': 374,
#  'matroid': 50219,
#  'shallowest': 375,
#  'eva': 50220,
#  'morbidly': 376,
#  'alderman': 377,
#  'clubbed': 40640,
#  'contacts': 378,
#  'lenis': 379,
#  'krc': 2292,
#  'truthhood': 62,
#  'fme': 2298,
#  'giantesses': 50224,
#  'locusts': 50225,
#  'lantfrid': 382,
#  'omniscience': 25910,
#  'stewardship': 383,
#  'rond': 384,
#  'musial': 385,
#  'vnd': 2316,
#  'artificer': 50227,
#  'renteria': 50228,
#  'nomura': 50229,
#  'supersonics': 2323,
#  'psychoanalyst': 50231,
#  'perseveres': 386,
#  'bovary': 387,
#  'smoggy': 50233,
#  'explicable': 388,
#  'entartete': 50234,
#  'strangelove': 50235,
#  'their': 50237,
#  'lug': 99656,
#  'spirituals': 389,
#  'mcmahon': 50238,
#  'sight': 50239,
#  'jubatus': 390,
#  'fastlane': 50240,
#  'picqa': 50241,
#  'counterclaims': 391,
#  'nool': 2360,
#  'constellation': 50242,
#  'rnu': 2362,
#  'unusual': 393,
#  'execution': 394,
#  'farrakhan': 395,
#  'work': 50244,
#  'gruppenf': 396,
#  'fuel': 397,
#  'undecided': 398,
#  'arizonac': 399,
#  'hwicce': 50246,
#  'iaith': 50247,
#  'demanded': 400,
#  'fad': 401,
#  'pengo': 58889,
#  'acutely': 2418,
#  'empire': 50249,
#  'seatbelts': 26013,
#  'streamflows': 402,
#  'reni': 50251,
#  'chaitanya': 403,
#  'khosrow': 2432,
#  'royalist': 404,
#  'gully': 405,
#  'ribose': 406,
#  'valves': 407,
#  'preservatives': 50256,
#  'torana': 2442,
#  'carbatrol': 408,
#  'mulholland': 50259,
#  'banning': 50260,
#  'oxfordshire': 409,
#  'yeshu': 50261,
#  'tiefland': 410,
#  'palatalization': 2472,
#  'pecking': 412,
#  'lafayette': 14157,
#  'hieroglyphs': 12516,
#  'materials': 75289,
#  'kyrgyzstani': 413,
#  'transplantation': 50264,
#  'circumstance': 66990,
#  'asterid': 50265,
#  'surpassed': 415,
#  'susilo': 50267,
#  'paddy': 49894,
#  'urbina': 50268,
#  'typewritten': 50269,
#  'propan': 416,
#  'hivites': 50270,
#  'wore': 50271,
#  'reevaluation': 417,
#  'faludi': 418,
#  'dissolving': 50272,
#  'shane': 419,
#  'borge': 2545,
#  'schein': 420,
#  'presqu': 421,
#  'hiss': 422,
#  'lagenodelphis': 50274,
#  'vicious': 424,
#  'sangita': 40999,
#  'graces': 425,
#  'poset': 426,
#  'leena': 50275,
#  'ndische': 33387,
#  'bayonne': 428,
#  'plenary': 50276,
#  'hondo': 429,
#  'genial': 50278,
#  'politicization': 2585,
#  'members': 430,
#  'mul': 431,
#  'gothenburg': 432,
#  'pelly': 433,
#  'thylacine': 50279,
#  'witbrock': 434,
#  'tatian': 50280,
#  'tell': 436,
#  'nexus': 50281,
#  'photosensitivity': 50282,
#  'stephanus': 437,
#  'fullest': 438,
#  'register': 439,
#  'counterfactually': 50283,
#  'carboxylate': 50284,
#  'agoult': 440,
#  'gondwana': 50285,
#  'polarized': 441,
#  'bodhi': 50286,
#  'grassalkovich': 442,
#  'disturb': 443,
#  'flo': 444,
#  'corwin': 445,
#  'plummet': 50288,
#  'teeing': 2673,
#  'eddahab': 16919,
#  'terni': 50289,
#  'unconcerned': 447,
#  'mize': 448,
#  'eject': 449,
#  'vengeance': 50290,
#  'cougar': 450,
#  'antiwar': 50292,
#  'hoagy': 452,
#  'hyperphysics': 453,
#  'nullified': 454,
#  'assun': 455,
#  'flawlessly': 50293,
#  'problem': 456,
#  'abhi': 457,
#  'senile': 91699,
#  'tightens': 50294,
#  'poulenc': 50295,
#  'acertain': 48210,
#  'vert': 50296,
#  'disintegrates': 458,
#  'transmutations': 50298,
#  'harsha': 459,
#  'interfaith': 461,
#  'psycho': 50299,
#  'liberalizing': 50300,
#  'eusociality': 462,
#  'elebi': 50301,
#  'impis': 16920,
#  'jacobian': 463,
#  'brno': 464,
#  'crennel': 50303,
#  'trucial': 50304,
#  'distrustful': 50305,
#  'meanest': 50306,
#  'swallows': 50307,
#  'clarifies': 96664,
#  'aorta': 50308,
#  'straddled': 50309,
#  'forgetting': 84977,
#  'hofert': 50310,
#  'aerial': 50311,
#  'steelworkers': 50312,
#  'karnak': 50313,
#  'aloxi': 466,
#  'bartolom': 467,
#  'secretly': 50314,
#  'mendoza': 50316,
#  'yogi': 50317,
#  'anchor': 91796,
#  'therapsids': 468,
#  'sheik': 50318,
#  'subcommittee': 469,
#  'twirling': 470,
#  'outcomes': 50319,
#  'imagined': 50320,
#  'answerability': 50321,
#  'ladino': 49900,
#  'miami': 50322,
#  'substring': 472,
#  'diaz': 473,
#  'spottiswoode': 50323,
#  'lui': 2847,
#  'uis': 2850,
#  'slither': 474,
#  'alde': 475,
#  'groulx': 476,
#  'youssoufi': 50327,
#  'lucrative': 50328,
#  'capitalization': 477,
#  'relay': 50329,
#  'flintlock': 478,
#  'esperanto': 50330,
#  'bureaucratic': 479,
#  'saivism': 50331,
#  'vestige': 90543,
#  'creeps': 480,
#  'redeemer': 481,
#  'zina': 99842,
#  'paulsen': 482,
#  'devours': 2899,
#  'solow': 483,
#  'morgoth': 484,
#  'georgians': 485,
#  'capaldi': 2905,
#  'gerar': 8640,
#  'wereman': 486,
#  'murad': 50335,
#  'gaim': 487,
#  'existing': 16924,
#  'carry': 488,
#  'cabriolet': 50337,
#  'khattab': 489,
#  'irked': 490,
#  'leland': 50339,
#  'raaf': 491,
#  'canes': 492,
#  'beno': 50340,
#  'teilhard': 75295,
#  'amorgos': 494,
#  'akutagawa': 495,
#  'fansubs': 41636,
#  'konigsberg': 496,
#  'juridical': 497,
#  'halld': 50343,
#  'motorway': 498,
#  'plinths': 500,
#  'glottalized': 501,
#  'churning': 19389,
#  'coaches': 502,
#  'locator': 2998,
#  'jabr': 50348,
#  'castelli': 50349,
#  'interscope': 503,
#  'prodos': 50350,
#  'cka': 504,
#  'ntliche': 3008,
#  'symmachus': 50352,
#  'puma': 75298,
#  'gillette': 505,
#  'rawson': 3021,
#  'myrrha': 508,
#  'emperor': 509,
#  'transcribed': 50353,
#  'bromwich': 510,
#  ...}

# %%
def get_wordId_list():
    input_file = open("./data/text8.txt", encoding="utf-8")
    sentence = input_file.readline()
    wordId_list = []  # 一句中的所有word 对应的 id
    sentence = sentence.strip().split(' ')
    for i,word in enumerate(sentence):
        if i%1000000==0:
            print (i,len(sentence))
        try:
            word_id = word2id_dict[word]
            wordId_list.append(word_id)
        except:
            continue
    return wordId_list

# %%
wordId_list = get_wordId_list()
# Out:
# 0 17005207
# 1000000 17005207
# 2000000 17005207
# 3000000 17005207
# 4000000 17005207
# 5000000 17005207
# 6000000 17005207
# 7000000 17005207
# 8000000 17005207
# 9000000 17005207
# 10000000 17005207
# 11000000 17005207
# 12000000 17005207
# 13000000 17005207
# 14000000 17005207
# 15000000 17005207
# 16000000 17005207
# 17000000 17005207

# %%
wordId_list
# Out:
# [34082,
#  30219,
#  56435,
#  56350,
#  42682,
#  78940,
#  22308,
#  2027,
#  67152,
#  5683,
#  12313,
#  46866,
#  37768,
#  80120,
#  18872,
#  28271,
#  54429,
#  78940,
#  28271,
#  60778,
#  5495,
#  37681,
#  28271,
#  37442,
#  74799,
#  78940,
#  28271,
#  64204,
#  5495,
#  68444,
#  28271,
#  42682,
#  97571,
#  29682,
#  67152,
#  71001,
#  56350,
#  24664,
#  5853,
#  86269,
#  58494,
#  61294,
#  37179,
#  80804,
#  67152,
#  62608,
#  71231,
#  86269,
#  92922,
#  28271,
#  91966,
#  78940,
#  27710,
#  10356,
#  15157,
#  76868,
#  47830,
#  78221,
#  65253,
#  56435,
#  56350,
#  92639,
#  38942,
#  36741,
#  91737,
#  7021,
#  51221,
#  28271,
#  68737,
#  34082,
#  97571,
#  88432,
#  70143,
#  28271,
#  20413,
#  8024,
#  99432,
#  39498,
#  76222,
#  63652,
#  34082,
#  56435,
#  56350,
#  77624,
#  44197,
#  97571,
#  28271,
#  72514,
#  80804,
#  55821,
#  40751,
#  85830,
#  37681,
#  21389,
#  86015,
#  41220,
#  50823,
#  52307,
#  40751,
#  13484,
#  6025,
#  78940,
#  60236,
#  4639,
#  71231,
#  34082,
#  76868,
#  82650,
#  86269,
#  29432,
#  93761,
#  17925,
#  80804,
#  72866,
#  28271,
#  38486,
#  78940,
#  29998,
#  346,
#  4416,
#  28271,
#  22719,
#  28271,
#  68737,
#  65868,
#  56435,
#  56736,
#  51221,
#  36620,
#  10356,
#  74404,
#  44029,
#  40159,
#  52556,
#  71658,
#  7562,
#  40171,
#  52179,
#  73251,
#  56350,
#  49899,
#  26039,
#  29998,
#  27710,
#  71001,
#  95438,
#  78940,
#  60236,
#  40751,
#  87435,
#  56435,
#  29998,
#  77624,
#  75067,
#  37681,
#  5217,
#  85859,
#  346,
#  51221,
#  72866,
#  93761,
#  89064,
#  21557,
#  22152,
#  70965,
#  7536,
#  78940,
#  11463,
#  67560,
#  6154,
#  40439,
#  37681,
#  91737,
#  57389,
#  27234,
#  34082,
#  97571,
#  56736,
#  10818,
#  7021,
#  36741,
#  60236,
#  10356,
#  97571,
#  5683,
#  51221,
#  76868,
#  73522,
#  92639,
#  68655,
#  78940,
#  60236,
#  49631,
#  71384,
#  86269,
#  86015,
#  56350,
#  30916,
#  30238,
#  27710,
#  55024,
#  61916,
#  87804,
#  95689,
#  25258,
#  61805,
#  27710,
#  19504,
#  50244,
#  12884,
#  32807,
#  58920,
#  22470,
#  12505,
#  86269,
#  28526,
#  52307,
#  97571,
#  76868,
#  4236,
#  87804,
#  95689,
#  56350,
#  30238,
#  27710,
#  19504,
#  86015,
#  69221,
#  87804,
#  40222,
#  37681,
#  52327,
#  74141,
#  37681,
#  1994,
#  31318,
#  80804,
#  24853,
#  24121,
#  3673,
#  81643,
#  27710,
#  94784,
#  55335,
#  94461,
#  61805,
#  49089,
#  56736,
#  77879,
#  70258,
#  74141,
#  37681,
#  63033,
#  71001,
#  1693,
#  80804,
#  16175,
#  58331,
#  35046,
#  3609,
#  37178,
#  37681,
#  16854,
#  35564,
#  78940,
#  32498,
#  65059,
#  77132,
#  7562,
#  5063,
#  95092,
#  37681,
#  60548,
#  63864,
#  6646,
#  86269,
#  78384,
#  89934,
#  78898,
#  51221,
#  18872,
#  28271,
#  28271,
#  65868,
#  49871,
#  37681,
#  8403,
#  20232,
#  61805,
#  18563,
#  71001,
#  74017,
#  70143,
#  10436,
#  43985,
#  74141,
#  736,
#  25506,
#  61916,
#  71001,
#  50080,
#  37597,
#  78940,
#  69912,
#  87933,
#  86269,
#  74141,
#  37597,
#  46626,
#  28271,
#  51893,
#  78940,
#  28271,
#  22719,
#  43872,
#  86355,
#  37681,
#  66126,
#  37681,
#  17762,
#  28271,
#  86874,
#  78940,
#  28271,
#  40961,
#  95092,
#  78940,
#  28271,
#  67010,
#  28271,
#  30689,
#  78940,
#  22737,
#  50420,
#  4443,
#  75222,
#  16257,
#  40751,
#  4938,
#  15558,
#  86269,
#  86015,
#  44109,
#  54558,
#  78940,
#  16973,
#  34082,
#  48013,
#  11184,
#  71001,
#  69334,
#  3673,
#  78940,
#  77994,
#  44197,
#  61520,
#  80804,
#  28271,
#  30689,
#  46626,
#  31825,
#  95092,
#  30850,
#  49631,
#  31781,
#  80804,
#  28271,
#  75412,
#  76649,
#  76722,
#  86015,
#  66048,
#  48745,
#  10012,
#  15813,
#  36741,
#  28271,
#  30720,
#  53201,
#  70143,
#  4639,
#  81098,
#  49631,
#  52067,
#  48745,
#  29804,
#  28271,
#  54429,
#  7562,
#  91721,
#  61801,
#  3609,
#  25258,
#  12313,
#  22550,
#  75860,
#  72524,
#  28271,
#  25122,
#  78940,
#  28271,
#  60778,
#  37365,
#  326,
#  37681,
#  40751,
#  15558,
#  36741,
#  56108,
#  56435,
#  54558,
#  78940,
#  16973,
#  34082,
#  71001,
#  28271,
#  16973,
#  76322,
#  28271,
#  2027,
#  86269,
#  36620,
#  28271,
#  42682,
#  86269,
#  57197,
#  68998,
#  66124,
#  21552,
#  52556,
#  94784,
#  52015,
#  24692,
#  54334,
#  38576,
#  71001,
#  69334,
#  98656,
#  12308,
#  10462,
#  38665,
#  94256,
#  79118,
#  22737,
#  86361,
#  77648,
#  99078,
#  60503,
#  39199,
#  57358,
#  28271,
#  95565,
#  88033,
#  27710,
#  85242,
#  60548,
#  52590,
#  22719,
#  45806,
#  70993,
#  38531,
#  7562,
#  81464,
#  26301,
#  56435,
#  1017,
#  71001,
#  65868,
#  11184,
#  71231,
#  56350,
#  37382,
#  37681,
#  11658,
#  71001,
#  28271,
#  88033,
#  36827,
#  75860,
#  15157,
#  98662,
#  94490,
#  80804,
#  39199,
#  97571,
#  25258,
#  61805,
#  37681,
#  94978,
#  40751,
#  31825,
#  69334,
#  54109,
#  71001,
#  22737,
#  86361,
#  3142,
#  99078,
#  71001,
#  28271,
#  26352,
#  78940,
#  28271,
#  64204,
#  5495,
#  89934,
#  78898,
#  65108,
#  25258,
#  62266,
#  69256,
#  77624,
#  38608,
#  50823,
#  78898,
#  49058,
#  44029,
#  36620,
#  28271,
#  68737,
#  34082,
#  76363,
#  98147,
#  51221,
#  76374,
#  87435,
#  4639,
#  29107,
#  56435,
#  28271,
#  2027,
#  44315,
#  61805,
#  22000,
#  37681,
#  78898,
#  56435,
#  28271,
#  38433,
#  78940,
#  96149,
#  34082,
#  52179,
#  48745,
#  4639,
#  57464,
#  52590,
#  61805,
#  75860,
#  67684,
#  52329,
#  37681,
#  28271,
#  42682,
#  94784,
#  67060,
#  10551,
#  56435,
#  25258,
#  90305,
#  31835,
#  36741,
#  28271,
#  46274,
#  75498,
#  48745,
#  94969,
#  16284,
#  45268,
#  71001,
#  28271,
#  64204,
#  5495,
#  28271,
#  2027,
#  91737,
#  93614,
#  61805,
#  49832,
#  85261,
#  40746,
#  10356,
#  97571,
#  6568,
#  31781,
#  80804,
#  10356,
#  40172,
#  9530,
#  23315,
#  49832,
#  85261,
#  40746,
#  65108,
#  60236,
#  97571,
#  26301,
#  71001,
#  22737,
#  23416,
#  96883,
#  77648,
#  80804,
#  28271,
#  42682,
#  61805,
#  94784,
#  24293,
#  56435,
#  56350,
#  91737,
#  4729,
#  10356,
#  97571,
#  28354,
#  4639,
#  4217,
#  80804,
#  56108,
#  52904,
#  40746,
#  56435,
#  28271,
#  38433,
#  78940,
#  16973,
#  61805,
#  54743,
#  71001,
#  60236,
#  97571,
#  26301,
#  40746,
#  29316,
#  22470,
#  28271,
#  2662,
#  20190,
#  26301,
#  97571,
#  53755,
#  71001,
#  4639,
#  50244,
#  39199,
#  15613,
#  28271,
#  41164,
#  78940,
#  5063,
#  26301,
#  26429,
#  9530,
#  60503,
#  45037,
#  76374,
#  36782,
#  51377,
#  86269,
#  36620,
#  37681,
#  22308,
#  50237,
#  26301,
#  56435,
#  49631,
#  39561,
#  42092,
#  56435,
#  882,
#  21820,
#  28354,
#  66326,
#  71001,
#  43872,
#  95438,
#  40746,
#  18584,
#  60236,
#  39199,
#  61132,
#  43288,
#  67560,
#  28372,
#  76374,
#  56081,
#  51377,
#  86269,
#  36620,
#  78384,
#  64592,
#  37681,
#  96700,
#  71001,
#  84635,
#  22470,
#  49089,
#  78940,
#  88467,
#  37681,
#  38608,
#  40746,
#  68293,
#  86692,
#  78940,
#  65868,
#  85242,
#  39199,
#  61132,
#  51178,
#  49427,
#  25258,
#  3292,
#  26306,
#  60503,
#  67560,
#  37681,
#  95313,
#  98007,
#  19146,
#  28271,
#  56197,
#  78940,
#  50237,
#  97568,
#  30954,
#  97568,
#  75389,
#  85242,
#  91408,
#  28271,
#  87543,
#  78940,
#  46866,
#  25122,
#  49427,
#  71001,
#  6079,
#  4639,
#  29383,
#  52807,
#  80804,
#  52590,
#  22737,
#  29383,
#  66326,
#  70143,
#  28271,
#  97568,
#  78940,
#  1994,
#  21820,
#  98007,
#  74656,
#  68851,
#  89548,
#  71001,
#  84781,
#  1452,
#  77331,
#  25258,
#  55220,
#  30238,
#  51884,
#  29383,
#  86015,
#  43483,
#  65253,
#  86269,
#  45425,
#  34507,
#  22470,
#  6646,
#  86269,
#  28271,
#  71231,
#  78940,
#  6079,
#  40746,
#  68293,
#  61916,
#  3609,
#  60491,
#  74671,
#  64204,
#  46866,
#  37768,
#  17925,
#  37681,
#  69334,
#  98056,
#  3609,
#  35560,
#  71001,
#  28271,
#  5495,
#  78940,
#  22737,
#  23416,
#  96883,
#  23416,
#  71001,
#  65792,
#  40746,
#  68293,
#  44197,
#  78940,
#  26301,
#  97571,
#  50968,
#  10356,
#  94784,
#  23320,
#  71001,
#  56350,
#  3214,
#  78940,
#  37477,
#  66002,
#  69334,
#  31183,
#  37681,
#  52307,
#  40751,
#  13484,
#  6025,
#  78940,
#  56108,
#  78940,
#  69334,
#  61916,
#  28354,
#  94969,
#  60828,
#  23235,
#  72495,
#  63393,
#  81626,
#  89883,
#  68293,
#  23352,
#  71001,
#  69334,
#  28271,
#  18335,
#  37681,
#  43872,
#  528,
#  89883,
#  32653,
#  80804,
#  56736,
#  6568,
#  53720,
#  93761,
#  346,
#  18872,
#  28271,
#  88378,
#  78940,
#  22719,
#  26301,
#  56435,
#  56350,
#  90403,
#  40614,
#  51377,
#  71001,
#  58103,
#  37681,
#  28271,
#  86500,
#  88378,
#  78940,
#  27710,
#  3609,
#  17489,
#  37791,
#  7562,
#  21323,
#  71001,
#  28271,
#  14721,
#  93021,
#  78940,
#  27710,
#  80804,
#  28271,
#  67560,
#  40751,
#  43872,
#  28725,
#  39199,
#  57700,
#  23352,
#  37681,
#  56350,
#  60390,
#  78940,
#  71001,
#  85242,
#  67560,
#  29383,
#  29189,
#  71001,
#  44742,
#  78940,
#  58759,
#  39622,
#  88620,
#  10356,
#  94784,
#  71001,
#  50237,
#  91737,
#  55220,
#  86269,
#  15550,
#  94978,
#  28354,
#  77380,
#  26301,
#  43918,
#  64202,
#  87804,
#  70892,
#  19504,
#  25204,
#  25951,
#  95689,
#  86269,
#  90580,
#  86269,
#  83432,
#  28271,
#  91186,
#  86269,
#  77380,
#  26006,
#  26301,
#  37681,
#  60236,
#  48728,
#  76374,
#  71001,
#  56894,
#  12649,
#  80804,
#  97571,
#  56894,
#  528,
#  94978,
#  29467,
#  56435,
#  48728,
#  53198,
#  96944,
#  56435,
#  55984,
#  48728,
#  94256,
#  28271,
#  34842,
#  78940,
#  28271,
#  91186,
#  89883,
#  22127,
#  61132,
#  32040,
#  25258,
#  61805,
#  39199,
#  53720,
#  39622,
#  28271,
#  38942,
#  65527,
#  85392,
#  69334,
#  61916,
#  3609,
#  60491,
#  94461,
#  76363,
#  28187,
#  51221,
#  50823,
#  6025,
#  78940,
#  69334,
#  37626,
#  40751,
#  49950,
#  88033,
#  95790,
#  34082,
#  94973,
#  69167,
#  71001,
#  ...]

# %%
def get_batch_pairs(batch_size,window_size,index,word_pairs_queue):
    while len(word_pairs_queue) < batch_size:
        if index==len(wordId_list):
            index = 0
        for _ in range(1000):
            for i in range(max(index - window_size, 0),min(index + window_size + 1,len(wordId_list))):
                wordId_w = wordId_list[index]
                wordId_v = wordId_list[i]
                if index == i:  # 上下文=中心词 跳过
                    continue
                word_pairs_queue.append((wordId_w, wordId_v))
            index+=1
    result_pairs = []  # 返回mini-batch大小的正采样对
    for _ in range(batch_size):
        result_pairs.append(word_pairs_queue.popleft())
    return result_pairs

# %%
index = 0
word_pairs_queue = deque()
result_pairs = get_batch_pairs(32,3,index,word_pairs_queue)

# %%
result_pairs
# Out:
# [(34082, 30219),
#  (34082, 56435),
#  (34082, 56350),
#  (30219, 34082),
#  (30219, 56435),
#  (30219, 56350),
#  (30219, 42682),
#  (56435, 34082),
#  (56435, 30219),
#  (56435, 56350),
#  (56435, 42682),
#  (56435, 78940),
#  (56350, 34082),
#  (56350, 30219),
#  (56350, 56435),
#  (56350, 42682),
#  (56350, 78940),
#  (56350, 22308),
#  (42682, 30219),
#  (42682, 56435),
#  (42682, 56350),
#  (42682, 78940),
#  (42682, 22308),
#  (42682, 2027),
#  (78940, 56435),
#  (78940, 56350),
#  (78940, 42682),
#  (78940, 22308),
#  (78940, 2027),
#  (78940, 67152),
#  (22308, 56350),
#  (22308, 42682)]

# %%
def _init_sample_table():
    sample_table = []
    sample_table_size = 1e8
    pow_frequency = np.array(list(wordid_frequency_dict.values())) ** 0.75
    word_pow_sum = sum(pow_frequency)
    ratio_array = pow_frequency / word_pow_sum
    word_count_list = np.round(ratio_array * sample_table_size)
    for word_index, word_freq in enumerate(word_count_list):
        sample_table += [word_index] * int(word_freq)
    sample_table = np.array(sample_table)
    return sample_table

# %%
sample_table = _init_sample_table()

# %%
sample_table
# Out:
# array([     0,      0,      0, ..., 100037, 100037, 100037])

# %%
def get_negative_sampling(positive_pairs, neg_count):
    neg_v = np.random.choice(sample_table, size=(len(positive_pairs), neg_count)).tolist()
    return neg_v

# %%
neg_v = get_negative_sampling(result_pairs,3)

# %%
neg_v
# Out:
# [[60360, 87336, 8658],
#  [45008, 4792, 19654],
#  [51493, 76622, 68416],
#  [64869, 60789, 25258],
#  [36741, 21429, 38853],
#  [52013, 28271, 96883],
#  [85242, 73450, 88603],
#  [8019, 11007, 55982],
#  [566, 34793, 62701],
#  [9530, 77373, 43402],
#  [70379, 64592, 7312],
#  [91961, 86361, 91742],
#  [95919, 5394, 25887],
#  [84888, 56227, 28354],
#  [71227, 40136, 34004],
#  [7375, 96511, 5335],
#  [63117, 52056, 93130],
#  [30310, 75075, 29260],
#  [10356, 8793, 22742],
#  [61670, 85568, 4443],
#  [39683, 59619, 31380],
#  [46645, 64016, 50633],
#  [90470, 28271, 94784],
#  [54576, 97571, 58259],
#  [80686, 82799, 4232],
#  [70575, 42092, 88325],
#  [89653, 93213, 28271],
#  [85264, 58509, 37681],
#  [75440, 76374, 14359],
#  [32646, 86349, 80937],
#  [86653, 56435, 94461],
#  [56350, 32771, 68293]]
